# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# OUTPUT : 

# /kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls1_log_prod-appserver-log_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost17_wls2_jmx_prod-appserver_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls1_log_prod-appserver-log_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost08_wls2_log_prod-appserver-log_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls1_jmx_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls1_unix-process_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost07_wls1_log_prod-appserver-log_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost18_global_unix-global_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls2_log_prod-appserver-log_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost18_wls2_unix-process_prod-appserver_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost08_wls2_jmx_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_global_unix-global_prod-appserver_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls2_unix-process_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_wls2_unix-process_prod-appserver_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls2_unix-process_prod-appserver_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost07_wls1_unix-process_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_global_unix-global_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost08_wls2_log_prod-appserver-log_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost07_wls1_jmx_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_wls2_jmx_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost17_wls2_log_prod-appserver-log_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls2_jmx_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost18_wls1_jmx_prod-appserver_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_jmx_prod-appserver_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_wls1_log_prod-appserver-log_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost17_wls2_unix-process_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls2_jmx_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls1_log_prod-appserver-log_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost11_global_unix-global_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost11_wls1_jmx_prod-appserver_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost08_wls1_jmx_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls2_unix-process_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost18_global_unix-global_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls2_log_prod-appserver-log_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_global_unix-global_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_wls1_jmx_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost07_global_unix-global_prod-appserver_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_log_prod-appserver-log_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_jmx_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls1_jmx_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls2_jmx_prod-appserver_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls1_jmx_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost11_wls2_jmx_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls2_unix-process_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost09_wls1_jmx_prod-appserver_2014.09.17_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost17_wls2_log_prod-appserver-log_2014.09.19_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost18_global_unix-global_prod-appserver_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_unix-process_prod-appserver_2014.09.20_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls1_unix-process_prod-appserver_2014.09.18_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost15_wls2_jmx_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost07_wls2_jmx_prod-appserver_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls1_log_prod-appserver-log_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_jmx_prod-appserver_2014.09.21_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost08_wls2_log_prod-appserver-log_2014.09.16_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost11_wls1_unix-process_prod-appserver_2014.09.22_00.00.00.csv
# /kaggle/input/rawdata/2014/2014-CW-38/lphost14_wls2_unix-process_prod-appserver_2014.09.17_00.00.00.csv

# %% [markdown]
# EDA

# %% [markdown]
# ### About dataset :
# ## 1. Metrics measured from the OS
#     \Cpu\hi
#     \Cpu\id
#     \Cpu\ni
#     \Cpu\si
#     \Cpu\st
#     \Cpu\sy
#     \Cpu\us
#     \Cpu\wa
#     \Load\avg
#     \Load\max
#     \Load\min
#     \Memory\buffers
#     \Memory\free
#     \Memory\total
#     \Memory\used
#     \Swap\cached
#     \Swap\free
#     \Swap\total
#     \Swap\used
#     \Tasks\running
#     \Tasks\sleeping
#     \Tasks\stopped
#     \Tasks\total
#     \Tasks\zombie
#     \Uptime\up
#     \User\users
#
#
# ## 2.Metrics measured from the WebLogic Processes (exemplary for lphost06, wls1):
#
# @source09
# ExecuteQueueRuntime
# JDBCConnectionPoolRuntime
# JDBCDataSourceRuntime
# Stuck
# Type=JTARuntime
# java.lang
# .*
# .BCI.
# .TracingAspect.
# MXBean(com.bea:ApplicationRuntime=batchModules,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=batchModules2,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=batchModules3,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=bea_wls9_async_response,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=bea_wls_cluster_internal,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=bea_wls_deployment_internal,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=bea_wls_diagnostics,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=bea_wls_internal,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source01,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source02,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source03,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source04,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source05,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source06,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source07,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source08,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# MXBean(com.bea:ApplicationRuntime=source09,Name=default,ServerRuntime=i0_lphost06,Type=WorkManagerRuntime).StuckThreadCount
# -- more --
#
# ### 3. About processes
# * \Process(java)\CPU
# * \Process(java)\MEM
# * \Process(java)\NI
# * \Process(java)\PID
# * \Process(java)\PR
# * \Process(java)\RES
# * \Process(java)\S
# * \Process(java)\SHR
# * \Process(java)\TIME
# * \Process(java)\USER
# * \Process(java)\VIRT

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

#pd.set_option('max_columns', 200)

# %%
# Import dataframe
df1 = pd.read_csv('/kaggle/input/rawdata/2014/2014-CW-38/lphost06_wls1_log_prod-appserver-log_2014.09.19_00.00.00.csv')
# Data understandig
df1.shape
df1.head
# Out:
# <bound method NDFrame.head of                          Date       .*  Unnamed: 2
# 0     18.09.2014 00:00:38.352  237,608         NaN
# 1     18.09.2014 00:01:38.353  237,608         NaN
# 2     18.09.2014 00:02:38.354  237,608         NaN
# 3     18.09.2014 00:03:38.355  237,608         NaN
# 4     18.09.2014 00:04:38.356  237,608         NaN
# ...                       ...      ...         ...
# 1435  18.09.2014 23:55:40.283  237,608         NaN
# 1436  18.09.2014 23:56:40.284  237,608         NaN
# 1437  18.09.2014 23:57:40.285  237,608         NaN
# 1438  18.09.2014 23:58:40.286  237,608         NaN
# 1439  18.09.2014 23:59:40.287  237,608         NaN
#
# [1440 rows x 3 columns]>

# %%
df2 = pd.read_csv('/kaggle/input/rawdata/2014/2014-CW-38/lphost10_wls1_jmx_prod-appserver_2014.09.22_00.00.00.csv')
# Data understandig
df2.shape
df2.head
# Out:
# <bound method NDFrame.head of                          Date  *java.lang*  *@source09*  *Stuck*  \
# 0     21.09.2014 00:00:09.973           -1           -1       -1
# 1     21.09.2014 00:01:09.988           -1           -1       -1
# 2     21.09.2014 00:02:10.009           -1           -1       -1
# 3     21.09.2014 00:03:10.023           -1           -1       -1
# 4     21.09.2014 00:04:10.044           -1           -1       -1
# ...                       ...          ...          ...      ...
# 1435  21.09.2014 23:55:36.752           -1           -1       -1
# 1436  21.09.2014 23:56:36.773           -1           -1       -1
# 1437  21.09.2014 23:57:36.789           -1           -1       -1
# 1438  21.09.2014 23:58:36.811           -1           -1       -1
# 1439  21.09.2014 23:59:36.829           -1           -1       -1
#
#       *ExecuteQueueRuntime*  *JDBCConnectionPoolRuntime*  \
# 0                        -1                           -1
# ...

# %%
# Importing all the data files
